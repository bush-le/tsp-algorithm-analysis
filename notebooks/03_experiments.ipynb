# %% [markdown]
# # 03. Chạy Thí nghiệm & Thu thập Kết quả
#
# **Mục tiêu:** Đây là notebook "chính" của dự án. Nó sẽ:
#
# 1.  Định nghĩa một danh sách các vấn đề TSP (ví dụ: `berlin52`, `burma14`, `eil76`).
# 2.  Gọi **tất cả 10 thuật toán** từ thư mục `/algorithms/`.
# 3.  Chạy từng thuật toán trên từng vấn đề.
# 4.  Đo lường **thời gian chạy** (`time`) và **chi phí lộ trình** (`cost`).
# 5.  Tính toán **khoảng cách %** (`gap %`) so với giải pháp tối ưu (nếu có).
# 6.  Lưu tất cả dữ liệu thô vào một file `results/results.csv` duy nhất bằng `pandas`.
#
# Notebook này được thiết kế để chạy trong thời gian dài (có thể mất vài phút đến vài giờ tùy thuộc vào cấu hình).
#
# **LƯU Ý QUAN TRỌNG:** Các thuật toán Exact (`Brute Force`, `Held-Karp`) sẽ được **bỏ qua (skipped)** một cách có chủ đích trên các vấn đề lớn (`N > 10` hoặc `N > 21`) để tránh thời gian chạy vô tận.

# %% [markdown]
# ## 1. Thiết lập & Imports
#
# Chúng ta sẽ import `pandas` (để xử lý data) và `time` (để đo thời gian) cùng với tất cả các module thuật toán và tiện ích của chúng ta.

# %%
import sys
import os
import time
import pandas as pd
import numpy as np

# --- Cấu hình sys.path --- 
# Thêm thư mục gốc của dự án (cao hơn 'notebooks' một cấp) vào sys.path
# để chúng ta có thể import các module 'utils' và 'algorithms'
project_root = os.path.normpath(os.path.join(os.path.abspath(os.path.dirname("__file__")), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
    print(f"Đã thêm '{project_root}' vào sys.path")
else:
    print(f"'{project_root}' đã có trong sys.path")
    
# --- Import Utils --- 
from utils import data_loader
from utils import evaluator

# --- Import 10 Thuật toán --- 
# Exact
from algorithms import brute_force
from algorithms import held_karp
# Heuristics Cổ điển
from algorithms import nearest_neighbor
from algorithms import nearest_insertion
# Xấp xỉ
from algorithms import christofides
# Cải tiến
from algorithms import two_opt
# Metaheuristics
from algorithms import simulated_annealing
from algorithms import genetic_algorithm
from algorithms import ant_colony
from algorithms import tabu_search

print("Tất cả các module đã được import thành công.")
# Out:
# Đã thêm 'c:\Desktop\Documents\GitHub\tsp-algorithm-analysis' vào sys.path
# Tất cả các module đã được import thành công.

# %% [markdown]
# ## 2. Cấu hình Thí nghiệm
#
# Định nghĩa các vấn đề chúng ta muốn chạy và các siêu tham số (hyperparameters) cho các thuật toán Metaheuristic.

# %%
# --- TỰ ĐỘNG QUÉT (VÀ LỌC) CÁC VẤN ĐỀ ĐỂ CHẠY ---
DATA_DIR = '../data'
RESULTS_FILE = '../results/results.csv'

# Nơi chứa các file .tsp
search_dirs = [
    os.path.join(DATA_DIR, 'tsplib'),
    os.path.join(DATA_DIR, 'generated')
]
# Nơi chứa các file .opt.tour (chuẩn)
optimum_dir = os.path.join(DATA_DIR, 'optimum_solutions')

problems_found = []
print(f"Đang quét tìm các file .tsp có file .opt.tour tương ứng...")

for directory in search_dirs:
    if os.path.isdir(directory):
        # print(f"Đang quét thư mục: {directory}...")
        for filename in os.listdir(directory):
            if filename.endswith(".tsp"):
                problem_name = filename.replace(".tsp", "")
                
                # --- ĐÂY LÀ THAY ĐỔI QUAN TRỌNG ---
                # Kiểm tra xem file .opt.tour có tồn tại không
                opt_path = os.path.join(optimum_dir, f"{problem_name}.opt.tour")
                
                if os.path.exists(opt_path):
                    # Chỉ thêm vào danh sách nếu TÌM THẤY file .opt.tour
                    problems_found.append(problem_name)
                    # print(f"  -> Đã tìm thấy '{problem_name}' (có .opt.tour)")
                else:
                    # Bỏ qua nếu không có
                    # print(f"  -> Bỏ qua '{problem_name}' (không có .opt.tour)")
                    pass
                # --- KẾT THÚC THAY ĐỔI ---
    else:
        print(f"Cảnh báo: Không tìm thấy thư mục {directory}")

# Loại bỏ các file trùng lặp (nếu có) và sắp xếp lại
PROBLEMS_TO_RUN = sorted(list(set(problems_found)))

if not PROBLEMS_TO_RUN:
    print("LỖI: Không tìm thấy file .tsp nào CÓ KÈM file .opt.tour! Dừng thí nghiệm.")
    raise FileNotFoundError("Không tìm thấy bộ dữ liệu hợp lệ (tsp + opt.tour).")
else:
    print(f"\n--- ĐÃ TÌM THẤY {len(PROBLEMS_TO_RUN)} VẤN ĐỀ HỢP LỆ (CÓ .OPT.TOUR) ĐỂ CHẠY ---")
    print(PROBLEMS_TO_RUN)


# --- SIÊU THAM SỐ (HYPERPARAMETERS) --- 
# (Phần này giữ nguyên y hệt như cũ)

SA_PARAMS = {
    # Nhiệt độ ban đầu: Rất cao (10000.0). 
    'initial_temp': 10000.0,
    
    # Tốc độ nguội: Rất chậm (0.999). 
    'cooling_rate': 0.999,
    
    # Nhiệt độ tối thiểu: Điểm dừng.
    'min_temp': 0.1,
    
    # Số lần lặp tại mỗi mức nhiệt:
    'max_iterations_per_temp': 100
}

GA_PARAMS = {
    # Quy mô quần thể: 
    'population_size': 100,
    
    # Số thế hệ:
    'num_generations': 500,
    
    # Tỷ lệ đột biến:
    'mutation_rate': 0.15,
    
    # Kích thước tinh hoa:
    'elite_size': 5,
    
    # Kích thước giải đấu:
    'tournament_k': 5
}

ACO_PARAMS = {
    # Số lượng kiến:
    'num_ants': 50, 
    
    # Số vòng lặp:
    'num_iterations': 100,
    
    # Trọng số Pheromone (alpha):
    'alpha': 1.0, 
    
    # Trọng số Tầm nhìn (beta):
    'beta': 5.0, 
    
    # Tốc độ bay hơi:
    'evaporation_rate': 0.5,
    
    # Lượng Pheromone gửi:
    'pheromone_deposit': 100.0
}

TS_PARAMS = {
    # Số lần lặp tối đa:
    'max_iterations': 2000,
    
    # Nhiệm kỳ cấm (Trí nhớ):
    'tabu_tenure': 30 
}
# Out:
# Đang quét tìm các file .tsp có file .opt.tour tương ứng...
#
# --- ĐÃ TÌM THẤY 31 VẤN ĐỀ HỢP LỆ (CÓ .OPT.TOUR) ĐỂ CHẠY ---
# ['a280', 'att48', 'bayg29', 'bays29', 'berlin52', 'ch130', 'ch150', 'eil101', 'eil51', 'eil76', 'fri26', 'gr120', 'gr202', 'gr24', 'gr48', 'gr666', 'gr96', 'kroA100', 'kroC100', 'kroD100', 'lin105', 'pa561', 'pcb442', 'pr1002', 'pr2392', 'pr76', 'rd100', 'st70', 'tsp225', 'ulysses16', 'ulysses22']

# %%
import pandas as pd
import os

# --- TẢI KẾT QUẢ CŨ ĐỂ KIỂM TRA ---
if os.path.exists(RESULTS_FILE):
    print(f"Đã tìm thấy file kết quả cũ. Đang tải: {RESULTS_FILE}")
    try:
        df_existing = pd.read_csv(RESULTS_FILE)
    except pd.errors.EmptyDataError:
        print("Cảnh báo: File kết quả cũ bị rỗng. Sẽ tạo file mới.")
        df_existing = pd.DataFrame(columns=['problem', 'algorithm'])
else:
    print(f"Không tìm thấy file kết quả cũ. Sẽ tạo file mới: {RESULTS_FILE}")
    df_existing = pd.DataFrame(columns=['problem', 'algorithm'])

# --- *** ĐỊNH NGHĨA HÀM TIỆN ÍCH BỊ THIẾU *** ---
# (Thêm hàm này vào)
def check_if_run_needed(df_existing, problem_name, algo_name):
    """
    Kiểm tra xem một cặp (problem, algorithm) đã tồn tại trong 
    DataFrame kết quả hay chưa.
    """
    if df_existing.empty:
        return True
    
    # Kiểm tra xem có bất kỳ hàng nào khớp với cả hai điều kiện không
    run_exists = ((df_existing['problem'] == problem_name) & 
                  (df_existing['algorithm'] == algo_name)).any()
    
    # Nếu đã tồn tại (run_exists = True) -> Không cần chạy (return False)
    return not run_exists

print("Hàm 'check_if_run_needed' đã được định nghĩa.")
# Out:
# Không tìm thấy file kết quả cũ. Sẽ tạo file mới: ../results/results.csv
# Hàm 'check_if_run_needed' đã được định nghĩa.

# %% [markdown]
# ## 3. Vòng lặp Thí nghiệm Chính
#
# Đây là nơi công việc nặng nhọc diễn ra. Chúng ta lặp qua từng vấn đề, sau đó lặp qua từng thuật toán, ghi lại kết quả.

# %%
# Danh sách để lưu tất cả kết quả
all_results = []

# (Giả định 'df_existing' và 'check_if_run_needed' đã được định nghĩa ở cell trên)

print(f"\n--- BẮT ĐẦU THÍ NGHIỆM CHO {len(PROBLEMS_TO_RUN)} VẤN ĐỀ ---")

for problem_name in PROBLEMS_TO_RUN:
    print(f"\n{'='*10} ĐANG XỬ LÝ: {problem_name.upper()} {'='*10}")
    
    # --- 1. TẢI DỮ LIỆU ---
    try:
        coords, matrix = data_loader.load_tsp_problem(problem_name, DATA_DIR)
        if matrix is None: raise ValueError("Không thể tải ma trận.")
        dim = len(matrix)
        opt_tour, opt_cost = data_loader.load_optimum_solution(problem_name, DATA_DIR, matrix)
        
        print(f"Đã tải {problem_name} (N={dim}), Chi phí tối ưu: {opt_cost}")
        
        if opt_cost == 0 and problem_name not in ['test_problem_no_opt']: 
             print(f"CẢNH BÁO NGHIÊM TRỌNG: Chi phí tối ưu = 0. File .opt.tour có thể bị lỗi!")

    except Exception as e:
        print(f"LỖI: Không thể xử lý {problem_name}. Lỗi: {e}. Bỏ qua.")
        continue

    # --- HÀM TRỢ GIÚP GHI KẾT QUẢ ---
    def record_result(algo_name, tour, cost, exec_time):
        if not check_if_run_needed(df_existing, problem_name, algo_name):
            print(f" -> Bỏ qua {algo_name} (đã chạy trước đó).")
            return
        
        gap = evaluator.calculate_gap(cost, opt_cost) # Dùng hàm chuẩn
        
        all_results.append({
            'problem': problem_name,
            'num_cities': dim,
            'algorithm': algo_name,
            'cost': int(cost),
            'opt_cost': int(opt_cost),
            'gap_percent': gap,
            'time_sec': exec_time
        })
        print(f"  [KẾT QUẢ] {algo_name:<20} | Cost: {int(cost):<8} | Gap: {gap:>6.2f}% | Time: {exec_time:>6.3f}s")

    # --- CHẠY 10 THUẬT TOÁN --- 
    
    # --- 1. Nearest Neighbor (ĐÃ SỬA LỖI) --- 
    algo_name = 'Nearest Neighbor'
    if check_if_run_needed(df_existing, problem_name, algo_name):
        print(f"  Đang chạy: {algo_name}...")
        start_time = time.perf_counter()
        
        # SỬA LỖI: Gọi hàm 'solve' đơn giản
        nn_tour, nn_cost = nearest_neighbor.solve(matrix, start_node=0)
                                                
        exec_time = time.perf_counter() - start_time
        record_result(algo_name, nn_tour, nn_cost, exec_time)
    else:
        print(f"  Bỏ qua {algo_name} (đã chạy trước đó).")
        # Vẫn phải chạy lại để lấy tour cho các thuật toán sau
        nn_tour, nn_cost = nearest_neighbor.solve(matrix, start_node=0)

    # --- 2. Nearest Insertion (ĐÃ SỬA LỖI) --- 
    algo_name = 'Nearest Insertion'
    if check_if_run_needed(df_existing, problem_name, algo_name):
        print(f"  Đang chạy: {algo_name}...")
        start_time = time.perf_counter()
        
        # SỬA LỖI: Gọi hàm 'solve' đơn giản
        ni_tour, ni_cost = nearest_insertion.solve(matrix, start_node=0)
                                                 
        exec_time = time.perf_counter() - start_time
        record_result(algo_name, ni_tour, ni_cost, exec_time)

    # --- 3. Christofides --- 
    algo_name = 'Christofides'
    if check_if_run_needed(df_existing, problem_name, algo_name):
        print(f"  Đang chạy: {algo_name}...")
        start_time = time.perf_counter()
        try:
            chris_tour, chris_cost = christofides.solve(matrix)
            exec_time = time.perf_counter() - start_time
            record_result(algo_name, chris_tour, chris_cost, exec_time)
        except Exception as e:
            print(f"  BỎ QUA: Christofides thất bại (Lỗi: {e})")
    
    # --- 4. 2-Opt (từ kết quả NN) --- 
    algo_name = '2-Opt' 
    if check_if_run_needed(df_existing, problem_name, algo_name):
        print(f"  Đang chạy: {algo_name} (from NN)...")
        start_time = time.perf_counter()
        
        # 2-Opt nhận 'nn_tour' (chưa tối ưu)
        two_opt_tour, two_opt_cost = two_opt.solve(matrix, initial_tour=nn_tour) 
        
        exec_time = time.perf_counter() - start_time
        record_result(algo_name, two_opt_tour, two_opt_cost, exec_time)

    # --- 5. Simulated Annealing (từ kết quả NN) --- 
    algo_name = 'Simulated Annealing'
    if check_if_run_needed(df_existing, problem_name, algo_name):
        print(f"  Đang chạy: {algo_name} (from NN)...")
        start_time = time.perf_counter()
        sa_tour, sa_cost = simulated_annealing.solve(matrix, initial_tour=nn_tour, **SA_PARAMS)
        exec_time = time.perf_counter() - start_time
        record_result(algo_name, sa_tour, sa_cost, exec_time)

    # --- 6. Genetic Algorithm --- 
    algo_name = 'Genetic Algorithm'
    if check_if_run_needed(df_existing, problem_name, algo_name):
        print(f"  Đang chạy: {algo_name}...")
        start_time = time.perf_counter()
        ga_tour, ga_cost = genetic_algorithm.solve(matrix, **GA_PARAMS)
        exec_time = time.perf_counter() - start_time
        record_result(algo_name, ga_tour, ga_cost, exec_time)

    # --- 7. Ant Colony Optimization --- 
    algo_name = 'ACO'
    if check_if_run_needed(df_existing, problem_name, algo_name):
        print(f"  Đang chạy: {algo_name}...")
        start_time = time.perf_counter()
        aco_tour, aco_cost = ant_colony.solve(matrix, **ACO_PARAMS)
        exec_time = time.perf_counter() - start_time
        record_result(algo_name, aco_tour, aco_cost, exec_time)

    # --- 8. Tabu Search (từ kết quả NN) --- 
    algo_name = 'Tabu Search'
    if check_if_run_needed(df_existing, problem_name, algo_name):
        print(f"  Đang chạy: {algo_name} (from NN)...")
        start_time = time.perf_counter()
        ts_tour, ts_cost = tabu_search.solve(matrix, initial_tour=nn_tour, **TS_PARAMS)
        exec_time = time.perf_counter() - start_time
        record_result(algo_name, ts_tour, ts_cost, exec_time)

    # --- 9. Brute Force (Giữ nguyên) --- 
    algo_name = 'Brute Force'
    if dim <= 10: 
        if check_if_run_needed(df_existing, problem_name, algo_name):
            print(f"  Đang chạy: {algo_name} (N<=10)...")
            start_time = time.perf_counter()
            bf_tour, bf_cost = brute_force.solve(matrix)
            exec_time = time.perf_counter() - start_time
            record_result(algo_name, bf_tour, bf_cost, exec_time)
    else:
        print(f"  BỎ QUA: Brute Force (N={dim} > 10)")

    # --- 10. Held-Karp (Giữ nguyên) --- 
    algo_name = 'Held-Karp'
    if dim <= 21: 
        if check_if_run_needed(df_existing, problem_name, algo_name):
            print(f"  Đang chạy: {algo_name} (N<=21)...")
            start_time = time.perf_counter()
            hk_tour, hk_cost = held_karp.solve(matrix)
            exec_time = time.perf_counter() - start_time
            record_result(algo_name, hk_tour, hk_cost, exec_time)
    else:
        print(f"  BỎ QUA: Held-Karp (N={dim} > 21)")
        
    print(f"--- Hoàn thành {problem_name.upper()} ---\n")

print("\n--- TẤT CẢ THÍ NGHIỆM HOÀN TẤT ---\n")
# Out:
# --- BẮT ĐẦU THÍ NGHIỆM CHO 31 VẤN ĐỀ ---
#
# ========== ĐANG XỬ LÝ: A280 ==========
# Đã tải a280 (N=280), Chi phí tối ưu: 2579
#   Đang chạy: Nearest Neighbor...
#   [KẾT QUẢ] Nearest Neighbor     | Cost: 3157     | Gap:  22.41% | Time:  0.001s
#   Đang chạy: Nearest Insertion...
#   [KẾT QUẢ] Nearest Insertion    | Cost: 3094     | Gap:  19.97% | Time:  0.046s
#   Đang chạy: Christofides...
#   [KẾT QUẢ] Christofides         | Cost: 2914     | Gap:  12.99% | Time:  0.622s
#   Đang chạy: 2-Opt (from NN)...
#   [KẾT QUẢ] 2-Opt                | Cost: 2767     | Gap:   7.29% | Time:  0.668s
#   Đang chạy: Simulated Annealing (from NN)...
#   [KẾT QUẢ] Simulated Annealing  | Cost: 2853     | Gap:  10.62% | Time:  5.642s
#   Đang chạy: Genetic Algorithm...
# [Gen   1] Best=  3109, Current=  3109, Diversity=100.0%, MutRate=15.0%, NoImprove=0
# [Gen   2] Best=  3109, Current=  3109, Diversity=97.0%, MutRate=15.0%, NoImprove=1
# [Gen   3] Best=  3109, Current=  3109, Diversity=99.0%, MutRate=15.0%, NoImprove=2
# [Gen   4] Best=  3109, Current=  3109, Diversity=96.0%, MutRate=15.0%, NoImprove=3
# [Gen   5] Best=  3109, Current=  3109, Diversity=92.0%, MutRate=15.0%, NoImprove=4
# [Gen  50] Best=  3102, Current=  3102, Diversity=33.0%, MutRate=30.0%, NoImprove=42
# [Gen 54] Diversity 24.0% < threshold, RESTARTING...
# [Gen 64] Diversity 13.0% < threshold, RESTARTING...
# [Gen 69] Diversity 16.0% < threshold, RESTARTING...
# [Gen 76] Diversity 12.0% < threshold, RESTARTING...
# [Gen 82] Diversity 10.0% < threshold, RESTARTING...
# [Gen 87] Diversity 16.0% < threshold, RESTARTING...
# [Gen 91] Diversity 23.0% < threshold, RESTARTING...
# [Gen 95] Diversity 23.0% < threshold, RESTARTING...
# [Gen 99] Diversity 19.0% < threshold, RESTARTING...
# [Gen 103] Diversity 9.0% < threshold, RESTARTING...
# [Gen 107] Diversity 18.0% < threshold, RESTARTING...
# [Gen 117] Diversity 16.0% < threshold, RESTARTING...
# [Gen 129] Diversity 18.0% < threshold, RESTARTING...
# [Gen 135] Diversity 22.0% < threshold, RESTARTING...
# [Gen 142] Diversity 20.0% < threshold, RESTARTING...
# [Gen 146] Diversity 12.0% < threshold, RESTARTING...
# [Gen 150] Best=  2975, Current=  2975, Diversity=58.0%, MutRate=15.0%, NoImprove=13
# [Gen 150] Diversity 18.0% < threshold, RESTARTING...
# [Gen 154] Diversity 20.0% < threshold, RESTARTING...
# [Gen 158] Diversity 12.0% < threshold, RESTARTING...
# [Gen 162] Diversity 22.0% < threshold, RESTARTING...
# [Gen 166] Diversity 12.0% < threshold, RESTARTING...
# [Gen 172] Diversity 23.0% < threshold, RESTARTING...
# [Gen 179] Diversity 19.0% < threshold, RESTARTING...
# [Gen 184] Diversity 24.0% < threshold, RESTARTING...
# [Gen 194] Diversity 24.0% < threshold, RESTARTING...
# [Gen 199] Diversity 12.0% < threshold, RESTARTING...
# [Gen 203] Diversity 16.0% < threshold, RESTARTING...
# [Gen 207] Diversity 22.0% < threshold, RESTARTING...
# [Gen 211] Diversity 21.0% < threshold, RESTARTING...
# [Gen 215] Diversity 14.0% < threshold, RESTARTING...
# [Gen 219] Diversity 22.0% < threshold, RESTARTING...
# [Gen 223] Diversity 16.0% < threshold, RESTARTING...
# [Gen 227] Diversity 23.0% < threshold, RESTARTING...
# [Gen 236] Diversity 21.0% < threshold, RESTARTING...
# [Gen 250] Best=  2969, Current=  2969, Diversity=30.0%, MutRate=30.0%, NoImprove=51
# [Gen 494] Diversity 21.0% < threshold, RESTARTING...
# [Gen 499] Diversity 19.0% < threshold, RESTARTING...
#   [KẾT QUẢ] Genetic Algorithm    | Cost: 2915     | Gap:  13.03% | Time: 40.972s
#   Đang chạy: ACO...
#   [KẾT QUẢ] ACO                  | Cost: 3077     | Gap:  19.31% | Time: 35.239s
#   Đang chạy: Tabu Search (from NN)...
#   [KẾT QUẢ] Tabu Search          | Cost: 2730     | Gap:   5.86% | Time: 80.401s
#   BỎ QUA: Brute Force (N=280 > 10)
#   BỎ QUA: Held-Karp (N=280 > 21)
# --- Hoàn thành A280 ---
#
#
# ========== ĐANG XỬ LÝ: ATT48 ==========
# Đã tải att48 (N=48), Chi phí tối ưu: 10598
#   Đang chạy: Nearest Neighbor...
#   [KẾT QUẢ] Nearest Neighbor     | Cost: 12832    | Gap:  21.08% | Time:  0.000s
#   Đang chạy: Nearest Insertion...
#   [KẾT QUẢ] Nearest Insertion    | Cost: 12012    | Gap:  13.34% | Time:  0.002s
#   Đang chạy: Christofides...
#   [KẾT QUẢ] Christofides         | Cost: 12583    | Gap:  18.73% | Time:  0.026s
#   Đang chạy: 2-Opt (from NN)...
#   [KẾT QUẢ] 2-Opt                | Cost: 10753    | Gap:   1.46% | Time:  0.008s
#   Đang chạy: Simulated Annealing (from NN)...
#   [KẾT QUẢ] Simulated Annealing  | Cost: 10598    | Gap:   0.00% | Time:  4.992s
#   Đang chạy: Genetic Algorithm...
# [Gen   1] Best= 11982, Current= 11982, Diversity=100.0%, MutRate=15.0%, NoImprove=0
# [Gen   2] Best= 11982, Current= 11982, Diversity=100.0%, MutRate=15.0%, NoImprove=1
# [Gen   3] Best= 11982, Current= 11982, Diversity=96.0%, MutRate=15.0%, NoImprove=2
# [Gen   4] Best= 11982, Current= 11982, Diversity=93.0%, MutRate=15.0%, NoImprove=3
# [Gen   5] Best= 11982, Current= 11982, Diversity=84.0%, MutRate=15.0%, NoImprove=4
# [Gen  50] Best= 11549, Current= 11549, Diversity=16.0%, MutRate=15.0%, NoImprove=9
# [Gen 51] Diversity 15.0% < threshold, RESTARTING...
# [Gen 55] Diversity 16.0% < threshold, RESTARTING...
# [Gen 60] Diversity 18.0% < threshold, RESTARTING...
# [Gen 64] Diversity 17.0% < threshold, RESTARTING...
# [Gen 68] Diversity 19.0% < threshold, RESTARTING...
# [Gen 72] Diversity 23.0% < threshold, RESTARTING...
# [Gen 77] Diversity 14.0% < threshold, RESTARTING...
# [Gen 81] Diversity 23.0% < threshold, RESTARTING...
# [Gen 86] Diversity 14.0% < threshold, RESTARTING...
# [Gen 90] Diversity 21.0% < threshold, RESTARTING...
# [Gen 94] Diversity 19.0% < threshold, RESTARTING...
# [Gen 98] Diversity 10.0% < threshold, RESTARTING...
# [Gen 100] Best= 11348, Current= 11348, Diversity=71.0%, MutRate=15.0%, NoImprove=15
# [Gen 102] Diversity 24.0% < threshold, RESTARTING...
# [Gen 106] Diversity 20.0% < threshold, RESTARTING...
# [Gen 454] Diversity 23.0% < threshold, RESTARTING...
# [Gen 465] Diversity 24.0% < threshold, RESTARTING...
# [Gen 477] Diversity 23.0% < threshold, RESTARTING...
# [Gen 482] Diversity 22.0% < threshold, RESTARTING...
# [Gen 490] Diversity 22.0% < threshold, RESTARTING...
# [Gen 498] Diversity 23.0% < threshold, RESTARTING...
# [Gen 500] Best= 10892, Current= 10892, Diversity=77.0%, MutRate=30.0%, NoImprove=240
#   [KẾT QUẢ] Genetic Algorithm    | Cost: 10892    | Gap:   2.77% | Time:  2.407s
#   Đang chạy: ACO...
#   [KẾT QUẢ] ACO                  | Cost: 11217    | Gap:   5.84% | Time:  4.864s
#   Đang chạy: Tabu Search (from NN)...
#   [KẾT QUẢ] Tabu Search          | Cost: 10878    | Gap:   2.64% | Time:  1.972s
#   BỎ QUA: Brute Force (N=48 > 10)
#   BỎ QUA: Held-Karp (N=48 > 21)
# --- Hoàn thành ATT48 ---
#
#
# ========== ĐANG XỬ LÝ: BAYG29 ==========
# Đã tải bayg29 (N=29), Chi phí tối ưu: 1610
#   Đang chạy: Nearest Neighbor...
#   [KẾT QUẢ] Nearest Neighbor     | Cost: 2005     | Gap:  24.53% | Time:  0.000s
#   Đang chạy: Nearest Insertion...
#   [KẾT QUẢ] Nearest Insertion    | Cost: 1759     | Gap:   9.26% | Time:  0.001s
#   Đang chạy: Christofides...
#   [KẾT QUẢ] Christofides         | Cost: 1765     | Gap:   9.63% | Time:  0.005s
#   Đang chạy: 2-Opt (from NN)...
#   [KẾT QUẢ] 2-Opt                | Cost: 1794     | Gap:  11.43% | Time:  0.002s
#   Đang chạy: Simulated Annealing (from NN)...
#   [KẾT QUẢ] Simulated Annealing  | Cost: 1610     | Gap:   0.00% | Time:  4.782s
#   Đang chạy: Genetic Algorithm...
# [Gen   1] Best=  1951, Current=  1951, Diversity=100.0%, MutRate=15.0%, NoImprove=0
# [Gen   2] Best=  1951, Current=  1951, Diversity=99.0%, MutRate=15.0%, NoImprove=1
# [Gen   3] Best=  1951, Current=  1951, Diversity=94.0%, MutRate=15.0%, NoImprove=2
# [Gen   4] Best=  1951, Current=  1951, Diversity=81.0%, MutRate=15.0%, NoImprove=3
# [Gen   5] Best=  1918, Current=  1918, Diversity=50.0%, MutRate=15.0%, NoImprove=0
# [Gen  50] Best=  1766, Current=  1766, Diversity=19.0%, MutRate=15.0%, NoImprove=15
# [Gen 51] Diversity 13.0% < threshold, RESTARTING...
# [Gen 55] Diversity 16.0% < threshold, RESTARTING...
# [Gen 60] Diversity 10.0% < threshold, RESTARTING...
# [Gen 64] Diversity 13.0% < threshold, RESTARTING...
# [Gen 70] Diversity 24.0% < threshold, RESTARTING...
# [Gen 74] Diversity 24.0% < threshold, RESTARTING...
# [Gen 80] Diversity 21.0% < threshold, RESTARTING...
# [Gen 88] Diversity 23.0% < threshold, RESTARTING...
# [Gen 94] Diversity 22.0% < threshold, RESTARTING...
# [Gen 100] Best=  1766, Current=  1766, Diversity=33.0%, MutRate=30.0%, NoImprove=65
#   [KẾT QUẢ] Tabu Search          | Cost: 1610     | Gap:   0.00% | Time:  0.714s
#   BỎ QUA: Brute Force (N=29 > 10)
#   BỎ QUA: Held-Karp (N=29 > 21)
# --- Hoàn thành BAYG29 ---
#
#
# ========== ĐANG XỬ LÝ: BAYS29 ==========
# Đã tải bays29 (N=29), Chi phí tối ưu: 2020
#   Đang chạy: Nearest Neighbor...
#   [KẾT QUẢ] Nearest Neighbor     | Cost: 2258     | Gap:  11.78% | Time:  0.000s
#   Đang chạy: Nearest Insertion...
#   [KẾT QUẢ] Nearest Insertion    | Cost: 2262     | Gap:  11.98% | Time:  0.001s
#   Đang chạy: Christofides...
#   [KẾT QUẢ] Christofides         | Cost: 2123     | Gap:   5.10% | Time:  0.007s
#   Đang chạy: 2-Opt (from NN)...
#   [KẾT QUẢ] 2-Opt                | Cost: 2064     | Gap:   2.18% | Time:  0.002s
#   Đang chạy: Simulated Annealing (from NN)...
#   [KẾT QUẢ] Simulated Annealing  | Cost: 2028     | Gap:   0.40% | Time:  4.893s
#   Đang chạy: Genetic Algorithm...
# [Gen   1] Best=  2258, Current=  2258, Diversity=100.0%, MutRate=15.0%, NoImprove=0
# [Gen   2] Best=  2214, Current=  2214, Diversity=96.0%, MutRate=15.0%, NoImprove=0
# [Gen   3] Best=  2214, Current=  2214, Diversity=91.0%, MutRate=15.0%, NoImprove=1
# [Gen   4] Best=  2214, Current=  2214, Diversity=69.0%, MutRate=15.0%, NoImprove=2
# [Gen   5] Best=  2214, Current=  2214, Diversity=50.0%, MutRate=15.0%, NoImprove=3
# [Gen  50] Best=  2067, Current=  2067, Diversity=19.0%, MutRate=15.0%, NoImprove=4
# [Gen 51] Diversity 16.0% < threshold, RESTARTING...
# [Gen 56] Diversity 17.0% < threshold, RESTARTING...
# [Gen 60] Diversity 18.0% < threshold, RESTARTING...
# [Gen 65] Diversity 19.0% < threshold, RESTARTING...
# [Gen 69] Diversity 23.0% < threshold, RESTARTING...
# [Gen 73] Diversity 15.0% < threshold, RESTARTING...
# [Gen 81] Diversity 23.0% < threshold, RESTARTING...
# [Gen 88] Diversity 20.0% < threshold, RESTARTING...
# [Gen 99] Diversity 23.0% < threshold, RESTARTING...
# [Gen 115] Diversity 21.0% < threshold, RESTARTING...
# [Gen 120] Diversity 23.0% < threshold, RESTARTING...
# [Gen 126] Diversity 21.0% < threshold, RESTARTING...
# [Gen 131] Diversity 23.0% < threshold, RESTARTING...
# [Gen 141] Diversity 18.0% < threshold, RESTARTING...
# [Gen 148] Diversity 21.0% < threshold, RESTARTING...
# [Gen 150] Best=  2067, Current=  2067, Diversity=66.0%, MutRate=30.0%, NoImprove=104
# [Gen 158] Diversity 24.0% < threshold, RESTARTING...
# [Gen 166] Diversity 24.0% < threshold, RESTARTING...
# [Gen 177] Diversity 24.0% < threshold, RESTARTING...
# [Gen 200] Best=  2067, Current=  2067, Diversity=33.0%, MutRate=30.0%, NoImprove=154
# [Gen 208] Diversity 24.0% < threshold, RESTARTING...
# [Gen 215] Diversity 22.0% < threshold, RESTARTING...
# [Gen 226] Diversity 20.0% < threshold, RESTARTING...
# [Gen 231] Diversity 24.0% < threshold, RESTARTING...
# [Gen 238] Diversity 17.0% < threshold, RESTARTING...
# [Gen 245] Diversity 24.0% < threshold, RESTARTING...
# [Gen 250] Best=  2048, Current=  2048, Diversity=27.0%, MutRate=15.0%, NoImprove=1
# [Gen 250] Diversity 23.0% < threshold, RESTARTING...
# [Gen 254] Diversity 22.0% < threshold, RESTARTING...
# [Gen 258] Diversity 18.0% < threshold, RESTARTING...
# [Gen 263] Diversity 14.0% < threshold, RESTARTING...
# [Gen 267] Diversity 23.0% < threshold, RESTARTING...
# [Gen 272] Diversity 15.0% < threshold, RESTARTING...
# [Gen 277] Diversity 10.0% < threshold, RESTARTING...
# [Gen 281] Diversity 22.0% < threshold, RESTARTING...
# [Gen 287] Diversity 23.0% < threshold, RESTARTING...
# [Gen 300] Best=  2048, Current=  2048, Diversity=31.0%, MutRate=30.0%, NoImprove=51
# [Gen 304] Diversity 24.0% < threshold, RESTARTING...
# [Gen 316] Diversity 21.0% < threshold, RESTARTING...
# [Gen 323] Diversity 24.0% < threshold, RESTARTING...
# [Gen 330] Diversity 23.0% < threshold, RESTARTING...
# [Gen 338] Diversity 24.0% < threshold, RESTARTING...
# [Gen 344] Diversity 24.0% < threshold, RESTARTING...
# [Gen 350] Best=  2048, Current=  2048, Diversity=27.0%, MutRate=30.0%, NoImprove=101
# [Gen 356] Diversity 23.0% < threshold, RESTARTING...
# [Gen 365] Diversity 24.0% < threshold, RESTARTING...
# [Gen 371] Diversity 19.0% < threshold, RESTARTING...
# [Gen 378] Diversity 23.0% < threshold, RESTARTING...
# [Gen 383] Diversity 19.0% < threshold, RESTARTING...
# [Gen 388] Diversity 21.0% < threshold, RESTARTING...
# [Gen 400] Best=  2048, Current=  2048, Diversity=29.0%, MutRate=30.0%, NoImprove=151
# [Gen 411] Diversity 24.0% < threshold, RESTARTING...
# [Gen 417] Diversity 21.0% < threshold, RESTARTING...
# [Gen 426] Diversity 19.0% < threshold, RESTARTING...
# [Gen 435] Diversity 23.0% < threshold, RESTARTING...
# [Gen 443] Diversity 23.0% < threshold, RESTARTING...
# [Gen 448] Diversity 20.0% < threshold, RESTARTING...
# [Gen 450] Best=  2048, Current=  2048, Diversity=64.0%, MutRate=30.0%, NoImprove=201
# [Gen 465] Diversity 23.0% < threshold, RESTARTING...
# [Gen 469] Diversity 22.0% < threshold, RESTARTING...
# [Gen 479] Diversity 24.0% < threshold, RESTARTING...
# [Gen 487] Diversity 24.0% < threshold, RESTARTING...
# [Gen 495] Diversity 24.0% < threshold, RESTARTING...
# [Gen 500] Best=  2048, Current=  2048, Diversity=43.0%, MutRate=30.0%, NoImprove=251
#   [KẾT QUẢ] Genetic Algorithm    | Cost: 2048     | Gap:   1.39% | Time:  1.719s
#   Đang chạy: ACO...
#   [KẾT QUẢ] ACO                  | Cost: 2055     | Gap:   1.73% | Time:  3.012s
#   Đang chạy: Tabu Search (from NN)...
#   [KẾT QUẢ] Tabu Search          | Cost: 2020     | Gap:   0.00% | Time:  0.715s
#   BỎ QUA: Brute Force (N=29 > 10)
#   BỎ QUA: Held-Karp (N=29 > 21)
# --- Hoàn thành BAYS29 ---
#
#
# ========== ĐANG XỬ LÝ: BERLIN52 ==========
# Đã tải berlin52 (N=52), Chi phí tối ưu: 7542
#   Đang chạy: Nearest Neighbor...
#   [KẾT QUẢ] Nearest Neighbor     | Cost: 8980     | Gap:  19.07% | Time:  0.000s
#   Đang chạy: Nearest Insertion...
#   [KẾT QUẢ] Nearest Insertion    | Cost: 8991     | Gap:  19.21% | Time:  0.002s
#   Đang chạy: Christofides...
#   [KẾT QUẢ] Christofides         | Cost: 8591     | Gap:  13.91% | Time:  0.015s
#   Đang chạy: 2-Opt (from NN)...
#   [KẾT QUẢ] 2-Opt                | Cost: 7967     | Gap:   5.63% | Time:  0.005s
#   Đang chạy: Simulated Annealing (from NN)...
#   [KẾT QUẢ] Simulated Annealing  | Cost: 7542     | Gap:   0.00% | Time:  4.911s
#   Đang chạy: Genetic Algorithm...
# [Gen   1] Best=  8980, Current=  8980, Diversity=100.0%, MutRate=15.0%, NoImprove=0
# [Gen   2] Best=  8980, Current=  8980, Diversity=97.0%, MutRate=15.0%, NoImprove=1
# [Gen   3] Best=  8980, Current=  8980, Diversity=93.0%, MutRate=15.0%, NoImprove=2
# [Gen   4] Best=  8980, Current=  8980, Diversity=89.0%, MutRate=15.0%, NoImprove=3
# [Gen   5] Best=  8980, Current=  8980, Diversity=79.0%, MutRate=15.0%, NoImprove=4
# [Gen  50] Best=  8486, Current=  8486, Diversity=17.0%, MutRate=15.0%, NoImprove=8
# [Gen 51] Diversity 18.0% < threshold, RESTARTING...
# [Gen 56] Diversity 13.0% < threshold, RESTARTING...
# [Gen 62] Diversity 20.0% < threshold, RESTARTING...
# [Gen 66] Diversity 16.0% < threshold, RESTARTING...
# [Gen 70] Diversity 17.0% < threshold, RESTARTING...
# [Gen 74] Diversity 16.0% < threshold, RESTARTING...
# [Gen 78] Diversity 21.0% < threshold, RESTARTING...
# [Gen 82] Diversity 21.0% < threshold, RESTARTING...
# [Gen 86] Diversity 17.0% < threshold, RESTARTING...
# [Gen 90] Diversity 14.0% < threshold, RESTARTING...
# [Gen 95] Diversity 15.0% < threshold, RESTARTING...
# [Gen 100] Best=  7904, Current=  7904, Diversity=27.0%, MutRate=15.0%, NoImprove=25
# [Gen 100] Diversity 11.0% < threshold, RESTARTING...
# [Gen 104] Diversity 11.0% < threshold, RESTARTING...
# [Gen 109] Diversity 23.0% < threshold, RESTARTING...
# [Gen 115] Diversity 20.0% < threshold, RESTARTING...
# [Gen 122] Diversity 20.0% < threshold, RESTARTING...
# [Gen 131] Diversity 21.0% < threshold, RESTARTING...
# [Gen 138] Diversity 24.0% < threshold, RESTARTING...
# [Gen 148] Diversity 22.0% < threshold, RESTARTING...
# [Gen 150] Best=  7904, Current=  7904, Diversity=71.0%, MutRate=30.0%, NoImprove=75
# [Gen 474] Diversity 24.0% < threshold, RESTARTING...
# [Gen 479] Diversity 20.0% < threshold, RESTARTING...
# [Gen 500] Best=  7711, Current=  7711, Diversity=38.0%, MutRate=30.0%, NoImprove=164
#   [KẾT QUẢ] Genetic Algorithm    | Cost: 7711     | Gap:   2.24% | Time:  2.614s
#   Đang chạy: ACO...
#   [KẾT QUẢ] ACO                  | Cost: 7706     | Gap:   2.17% | Time:  5.389s
#   Đang chạy: Tabu Search (from NN)...
#   [KẾT QUẢ] Tabu Search          | Cost: 7542     | Gap:   0.00% | Time:  2.358s
#   BỎ QUA: Brute Force (N=52 > 10)
#   BỎ QUA: Held-Karp (N=52 > 21)
# --- Hoàn thành BERLIN52 ---
#
#
# ========== ĐANG XỬ LÝ: CH130 ==========
# Đã tải ch130 (N=130), Chi phí tối ưu: 6110
#   Đang chạy: Nearest Neighbor...
#   [KẾT QUẢ] Nearest Neighbor     | Cost: 7579     | Gap:  24.04% | Time:  0.001s
#   Đang chạy: Nearest Insertion...
#   [KẾT QUẢ] Nearest Insertion    | Cost: 7446     | Gap:  21.87% | Time:  0.009s
#   Đang chạy: Christofides...
#   [KẾT QUẢ] Christofides         | Cost: 6773     | Gap:  10.85% | Time:  0.096s
#   Đang chạy: 2-Opt (from NN)...
#   [KẾT QUẢ] 2-Opt                | Cost: 6682     | Gap:   9.36% | Time:  0.113s
#   Đang chạy: Simulated Annealing (from NN)...
#   [KẾT QUẢ] Simulated Annealing  | Cost: 6445     | Gap:   5.48% | Time:  5.134s
#   Đang chạy: Genetic Algorithm...
# [Gen   1] Best=  7129, Current=  7129, Diversity=100.0%, MutRate=15.0%, NoImprove=0
# [Gen   2] Best=  7129, Current=  7129, Diversity=99.0%, MutRate=15.0%, NoImprove=1
# [Gen   3] Best=  7129, Current=  7129, Diversity=96.0%, MutRate=15.0%, NoImprove=2
# [Gen   4] Best=  7129, Current=  7129, Diversity=95.0%, MutRate=15.0%, NoImprove=3
# [Gen   5] Best=  7129, Current=  7129, Diversity=92.0%, MutRate=15.0%, NoImprove=4
# [Gen  50] Best=  6883, Current=  6883, Diversity=16.0%, MutRate=15.0%, NoImprove=8
# [Gen 51] Diversity 20.0% < threshold, RESTARTING...
# [Gen 56] Diversity 12.0% < threshold, RESTARTING...
# [Gen 61] Diversity 13.0% < threshold, RESTARTING...
# [Gen 65] Diversity 13.0% < threshold, RESTARTING...
# [Gen 70] Diversity 17.0% < threshold, RESTARTING...
# [Gen 74] Diversity 22.0% < threshold, RESTARTING...
# [Gen 78] Diversity 19.0% < threshold, RESTARTING...
# [Gen 84] Diversity 19.0% < threshold, RESTARTING...
# [Gen 88] Diversity 22.0% < threshold, RESTARTING...
# [Gen 92] Diversity 15.0% < threshold, RESTARTING...
# [Gen 96] Diversity 23.0% < threshold, RESTARTING...
# [Gen 100] Best=  6820, Current=  6820, Diversity=45.0%, MutRate=15.0%, NoImprove=3
# [Gen 100] Diversity 15.0% < threshold, RESTARTING...
# [Gen 347] Diversity 24.0% < threshold, RESTARTING...
# [Gen 350] Best=  6713, Current=  6713, Diversity=81.0%, MutRate=30.0%, NoImprove=47
# [Gen 355] Diversity 22.0% < threshold, RESTARTING...
# [Gen 360] Diversity 16.0% < threshold, RESTARTING...
# [Gen 364] Diversity 18.0% < threshold, RESTARTING...
# [Gen 368] Diversity 24.0% < threshold, RESTARTING...
# [Gen 372] Diversity 19.0% < threshold, RESTARTING...
# [Gen 376] Diversity 15.0% < threshold, RESTARTING...
# [Gen 380] Diversity 16.0% < threshold, RESTARTING...
# [Gen 384] Diversity 20.0% < threshold, RESTARTING...
# [Gen 388] Diversity 13.0% < threshold, RESTARTING...
# [Gen 392] Diversity 15.0% < threshold, RESTARTING...
# [Gen 397] Diversity 17.0% < threshold, RESTARTING...
# [Gen 400] Best=  6685, Current=  6685, Diversity=83.0%, MutRate=15.0%, NoImprove=25
# [Gen 401] Diversity 19.0% < threshold, RESTARTING...
# [Gen 405] Diversity 18.0% < threshold, RESTARTING...
# [Gen 411] Diversity 15.0% < threshold, RESTARTING...
# [Gen 415] Diversity 17.0% < threshold, RESTARTING...
# [Gen 419] Diversity 19.0% < threshold, RESTARTING...
# [Gen 424] Diversity 12.0% < threshold, RESTARTING...
# [Gen 428] Diversity 21.0% < threshold, RESTARTING...
# [Gen 432] Diversity 19.0% < threshold, RESTARTING...
# [Gen 437] Diversity 12.0% < threshold, RESTARTING...
# [Gen 441] Diversity 21.0% < threshold, RESTARTING...
# [Gen 445] Diversity 19.0% < threshold, RESTARTING...
# [Gen 449] Diversity 19.0% < threshold, RESTARTING...
# [Gen 453] Diversity 20.0% < threshold, RESTARTING...
# [Gen 457] Diversity 23.0% < threshold, RESTARTING...
# [Gen 462] Diversity 6.0% < threshold, RESTARTING...
# [Gen 484] Diversity 17.0% < threshold, RESTARTING...
# [Gen 489] Diversity 19.0% < threshold, RESTARTING...
# [Gen 493] Diversity 18.0% < threshold, RESTARTING...
# [Gen 497] Diversity 17.0% < threshold, RESTARTING...
# [Gen 500] Best=  6622, Current=  6622, Diversity=87.0%, MutRate=15.0%, NoImprove=3
#   [KẾT QUẢ] Genetic Algorithm    | Cost: 6622     | Gap:   8.38% | Time: 11.218s
#   Đang chạy: ACO...
#   [KẾT QUẢ] ACO                  | Cost: 6596     | Gap:   7.95% | Time: 14.198s
#   Đang chạy: Tabu Search (from NN)...
#   [KẾT QUẢ] Tabu Search          | Cost: 6442     | Gap:   5.43% | Time: 15.294s
#   BỎ QUA: Brute Force (N=130 > 10)
#   BỎ QUA: Held-Karp (N=130 > 21)
# --- Hoàn thành CH130 ---
#
#
# ========== ĐANG XỬ LÝ: CH150 ==========
# Đã tải ch150 (N=150), Chi phí tối ưu: 6528
#   Đang chạy: Nearest Neighbor...
#   [KẾT QUẢ] Nearest Neighbor     | Cost: 8191     | Gap:  25.48% | Time:  0.001s
#   Đang chạy: Nearest Insertion...
#   [KẾT QUẢ] Nearest Insertion    | Cost: 7968     | Gap:  22.06% | Time:  0.014s
#   Đang chạy: Christofides...
#   [KẾT QUẢ] Christofides         | Cost: 7135     | Gap:   9.30% | Time:  0.124s
#   Đang chạy: 2-Opt (from NN)...
#   [KẾT QUẢ] 2-Opt                | Cost: 6886     | Gap:   5.48% | Time:  0.244s
#   Đang chạy: Simulated Annealing (from NN)...
#   [KẾT QUẢ] Simulated Annealing  | Cost: 6828     | Gap:   4.60% | Time:  5.254s
#   Đang chạy: Genetic Algorithm...
# [Gen   1] Best=  7157, Current=  7157, Diversity=100.0%, MutRate=15.0%, NoImprove=0
# [Gen   2] Best=  7157, Current=  7157, Diversity=99.0%, MutRate=15.0%, NoImprove=1
# [Gen   3] Best=  7157, Current=  7157, Diversity=99.0%, MutRate=15.0%, NoImprove=2
# [Gen   4] Best=  7140, Current=  7140, Diversity=90.0%, MutRate=15.0%, NoImprove=0
# [Gen   5] Best=  7140, Current=  7140, Diversity=73.0%, MutRate=15.0%, NoImprove=1
# [Gen  50] Best=  7087, Current=  7087, Diversity=15.0%, MutRate=15.0%, NoImprove=2
# [Gen 51] Diversity 15.0% < threshold, RESTARTING...
# [Gen 55] Diversity 15.0% < threshold, RESTARTING...
# [Gen 59] Diversity 11.0% < threshold, RESTARTING...
# [Gen 63] Diversity 15.0% < threshold, RESTARTING...
# [Gen 67] Diversity 17.0% < threshold, RESTARTING...
# [Gen 72] Diversity 17.0% < threshold, RESTARTING...
# [Gen 76] Diversity 19.0% < threshold, RESTARTING...
# [Gen 80] Diversity 12.0% < threshold, RESTARTING...
# [Gen 84] Diversity 14.0% < threshold, RESTARTING...
# [Gen 88] Diversity 12.0% < threshold, RESTARTING...
# [Gen 92] Diversity 11.0% < threshold, RESTARTING...
# [Gen 96] Diversity 17.0% < threshold, RESTARTING...
# [Gen 100] Best=  6967, Current=  6967, Diversity=51.0%, MutRate=15.0%, NoImprove=24
# [Gen 101] Diversity 13.0% < threshold, RESTARTING...
# [Gen 105] Diversity 17.0% < threshold, RESTARTING...
# [Gen 110] Diversity 24.0% < threshold, RESTARTING...
# [Gen 120] Diversity 16.0% < threshold, RESTARTING...
# [Gen 124] Diversity 17.0% < threshold, RESTARTING...
# [Gen 128] Diversity 24.0% < threshold, RESTARTING...
# [Gen 132] Diversity 16.0% < threshold, RESTARTING...
# [Gen 137] Diversity 14.0% < threshold, RESTARTING...
# [Gen 141] Diversity 14.0% < threshold, RESTARTING...
# [Gen 145] Diversity 18.0% < threshold, RESTARTING...
# [Gen 150] Best=  6960, Current=  6960, Diversity=25.0%, MutRate=15.0%, NoImprove=30
# [Gen 150] Diversity 11.0% < threshold, RESTARTING...
# [Gen 158] Diversity 22.0% < threshold, RESTARTING...
# [Gen 163] Diversity 22.0% < threshold, RESTARTING...
# [Gen 173] Diversity 23.0% < threshold, RESTARTING...
# [Gen 182] Diversity 22.0% < threshold, RESTARTING...
# [Gen 187] Diversity 21.0% < threshold, RESTARTING...
# [Gen 193] Diversity 22.0% < threshold, RESTARTING...
# [Gen 200] Best=  6960, Current=  6960, Diversity=34.0%, MutRate=30.0%, NoImprove=80
# [Gen 422] Diversity 18.0% < threshold, RESTARTING...
# [Gen 432] Diversity 24.0% < threshold, RESTARTING...
# [Gen 439] Diversity 16.0% < threshold, RESTARTING...
# [Gen 444] Diversity 19.0% < threshold, RESTARTING...
# [Gen 448] Diversity 15.0% < threshold, RESTARTING...
# [Gen 450] Best=  6895, Current=  6895, Diversity=82.0%, MutRate=15.0%, NoImprove=11
# [Gen 452] Diversity 18.0% < threshold, RESTARTING...
# [Gen 456] Diversity 21.0% < threshold, RESTARTING...
# [Gen 460] Diversity 20.0% < threshold, RESTARTING...
# [Gen 465] Diversity 13.0% < threshold, RESTARTING...
# [Gen 469] Diversity 15.0% < threshold, RESTARTING...
# [Gen 476] Diversity 24.0% < threshold, RESTARTING...
# [Gen 482] Diversity 18.0% < threshold, RESTARTING...
# [Gen 487] Diversity 17.0% < threshold, RESTARTING...
# [Gen 491] Diversity 18.0% < threshold, RESTARTING...
# [Gen 495] Diversity 21.0% < threshold, RESTARTING...
# [Gen 499] Diversity 18.0% < threshold, RESTARTING...
#   [KẾT QUẢ] Genetic Algorithm    | Cost: 6872     | Gap:   5.27% | Time: 13.982s
#   Đang chạy: ACO...
#   [KẾT QUẢ] ACO                  | Cost: 6786     | Gap:   3.95% | Time: 16.643s
#   Đang chạy: Tabu Search (from NN)...
#   [KẾT QUẢ] Tabu Search          | Cost: 6616     | Gap:   1.35% | Time: 20.287s
#   BỎ QUA: Brute Force (N=150 > 10)
#   BỎ QUA: Held-Karp (N=150 > 21)
# --- Hoàn thành CH150 ---
#
#
# ========== ĐANG XỬ LÝ: EIL101 ==========
# Đã tải eil101 (N=101), Chi phí tối ưu: 629
#   Đang chạy: Nearest Neighbor...
#   [KẾT QUẢ] Nearest Neighbor     | Cost: 803      | Gap:  27.66% | Time:  0.000s
#   Đang chạy: Nearest Insertion...
#   [KẾT QUẢ] Nearest Insertion    | Cost: 711      | Gap:  13.04% | Time:  0.005s
#   Đang chạy: Christofides...
#   [KẾT QUẢ] Christofides         | Cost: 707      | Gap:  12.40% | Time:  0.088s
#   Đang chạy: 2-Opt (from NN)...
#   [KẾT QUẢ] 2-Opt                | Cost: 658      | Gap:   4.61% | Time:  0.078s
#   Đang chạy: Simulated Annealing (from NN)...
#   [KẾT QUẢ] Simulated Annealing  | Cost: 664      | Gap:   5.56% | Time:  5.147s
#   Đang chạy: Genetic Algorithm...
# [Gen   1] Best=   777, Current=   777, Diversity=100.0%, MutRate=15.0%, NoImprove=0
# [Gen   2] Best=   777, Current=   777, Diversity=98.0%, MutRate=15.0%, NoImprove=1
# [Gen   3] Best=   777, Current=   777, Diversity=93.0%, MutRate=15.0%, NoImprove=2
# [Gen   4] Best=   777, Current=   777, Diversity=88.0%, MutRate=15.0%, NoImprove=3
# [Gen   5] Best=   777, Current=   777, Diversity=75.0%, MutRate=15.0%, NoImprove=4
# [Gen  50] Best=   762, Current=   762, Diversity=13.0%, MutRate=15.0%, NoImprove=14
# [Gen 51] Diversity 15.0% < threshold, RESTARTING...
# [Gen 298] Diversity 19.0% < threshold, RESTARTING...
# [Gen 300] Best=  4462, Current=  4462, Diversity=85.0%, MutRate=15.0%, NoImprove=10
# [Gen 303] Diversity 11.0% < threshold, RESTARTING...
# [Gen 307] Diversity 15.0% < threshold, RESTARTING...
# [Gen 311] Diversity 18.0% < threshold, RESTARTING...
# [Gen 315] Diversity 22.0% < threshold, RESTARTING...
# [Gen 319] Diversity 17.0% < threshold, RESTARTING...
# [Gen 334] Diversity 14.0% < threshold, RESTARTING...
# [Gen 339] Diversity 15.0% < threshold, RESTARTING...
# [Gen 343] Diversity 20.0% < threshold, RESTARTING...
# [Gen 348] Diversity 14.0% < threshold, RESTARTING...
# [Gen 350] Best=  4455, Current=  4455, Diversity=88.0%, MutRate=15.0%, NoImprove=16
# [Gen 352] Diversity 18.0% < threshold, RESTARTING...
# [Gen 356] Diversity 11.0% < threshold, RESTARTING...
# [Gen 360] Diversity 19.0% < threshold, RESTARTING...
# [Gen 364] Diversity 22.0% < threshold, RESTARTING...
# [Gen 371] Diversity 19.0% < threshold, RESTARTING...
# [Gen 375] Diversity 18.0% < threshold, RESTARTING...
# [Gen 379] Diversity 21.0% < threshold, RESTARTING...
# [Gen 383] Diversity 19.0% < threshold, RESTARTING...
# [Gen 387] Diversity 18.0% < threshold, RESTARTING...
# [Gen 392] Diversity 20.0% < threshold, RESTARTING...
# [Gen 396] Diversity 23.0% < threshold, RESTARTING...
# [Gen 400] Best=  4430, Current=  4430, Diversity=38.0%, MutRate=15.0%, NoImprove=21
# [Gen 400] Diversity 15.0% < threshold, RESTARTING...
# [Gen 405] Diversity 15.0% < threshold, RESTARTING...
# [Gen 409] Diversity 23.0% < threshold, RESTARTING...
# [Gen 416] Diversity 24.0% < threshold, RESTARTING...
# [Gen 425] Diversity 24.0% < threshold, RESTARTING...
# [Gen 434] Diversity 17.0% < threshold, RESTARTING...
# [Gen 442] Diversity 24.0% < threshold, RESTARTING...
# [Gen 447] Diversity 20.0% < threshold, RESTARTING...
# [Gen 450] Best=  4430, Current=  4430, Diversity=81.0%, MutRate=30.0%, NoImprove=71
# [Gen 457] Diversity 23.0% < threshold, RESTARTING...
# [Gen 463] Diversity 24.0% < threshold, RESTARTING...
# [Gen 470] Diversity 22.0% < threshold, RESTARTING...
# [Gen 476] Diversity 23.0% < threshold, RESTARTING...
# [Gen 500] Best=  4430, Current=  4430, Diversity=30.0%, MutRate=30.0%, NoImprove=121
#   [KẾT QUẢ] Genetic Algorithm    | Cost: 4430     | Gap:  14.74% | Time: 27.387s
#   Đang chạy: ACO...
#   [KẾT QUẢ] ACO                  | Cost: 4300     | Gap:  11.37% | Time: 24.602s
#   Đang chạy: Tabu Search (from NN)...
#   [KẾT QUẢ] Tabu Search          | Cost: 3971     | Gap:   2.85% | Time: 45.652s
#   BỎ QUA: Brute Force (N=225 > 10)
#   BỎ QUA: Held-Karp (N=225 > 21)
# --- Hoàn thành TSP225 ---
#
#
# ========== ĐANG XỬ LÝ: ULYSSES16 ==========
# Đã tải ulysses16 (N=16), Chi phí tối ưu: 6815
#   Đang chạy: Nearest Neighbor...
#   [KẾT QUẢ] Nearest Neighbor     | Cost: 9691     | Gap:  42.20% | Time:  0.000s
#   Đang chạy: Nearest Insertion...
#   [KẾT QUẢ] Nearest Insertion    | Cost: 7401     | Gap:   8.60% | Time:  0.000s
#   Đang chạy: Christofides...
#   [KẾT QUẢ] Christofides         | Cost: 6994     | Gap:   2.63% | Time:  0.002s
#   Đang chạy: 2-Opt (from NN)...
#   [KẾT QUẢ] 2-Opt                | Cost: 6815     | Gap:   0.00% | Time:  0.001s
#   Đang chạy: Simulated Annealing (from NN)...
#   [KẾT QUẢ] Simulated Annealing  | Cost: 6815     | Gap:   0.00% | Time:  4.910s
#   Đang chạy: Genetic Algorithm...
# [Gen   1] Best=  7985, Current=  7985, Diversity=100.0%, MutRate=15.0%, NoImprove=0
# [Gen   2] Best=  7985, Current=  7985, Diversity=96.0%, MutRate=15.0%, NoImprove=1
# [Gen   3] Best=  7739, Current=  7739, Diversity=91.0%, MutRate=15.0%, NoImprove=0
# [Gen   4] Best=  7739, Current=  7739, Diversity=73.0%, MutRate=15.0%, NoImprove=1
# [Gen   5] Best=  7739, Current=  7739, Diversity=67.0%, MutRate=15.0%, NoImprove=2
# [Gen  50] Best=  6872, Current=  6872, Diversity=22.0%, MutRate=30.0%, NoImprove=37
# [Gen 54] Diversity 23.0% < threshold, RESTARTING...
# [Gen 59] Diversity 19.0% < threshold, RESTARTING...
# [Gen 67] Diversity 20.0% < threshold, RESTARTING...
# [Gen 72] Diversity 16.0% < threshold, RESTARTING...
# [Gen 76] Diversity 22.0% < threshold, RESTARTING...
# [Gen 84] Diversity 19.0% < threshold, RESTARTING...
# [Gen 90] Diversity 24.0% < threshold, RESTARTING...
# [Gen 95] Diversity 23.0% < threshold, RESTARTING...
# [Gen 100] Best=  6872, Current=  6872, Diversity=31.0%, MutRate=30.0%, NoImprove=87
# [Gen 104] Diversity 22.0% < threshold, RESTARTING...
# [Gen 112] Diversity 22.0% < threshold, RESTARTING...
# [Gen 120] Diversity 23.0% < threshold, RESTARTING...
# [Gen 126] Diversity 24.0% < threshold, RESTARTING...
# [Gen 137] Diversity 23.0% < threshold, RESTARTING...
# [Gen 144] Diversity 24.0% < threshold, RESTARTING...
# [Gen 150] Best=  6872, Current=  6872, Diversity=25.0%, MutRate=30.0%, NoImprove=137
# [Gen 157] Diversity 22.0% < threshold, RESTARTING...
# [Gen 170] Diversity 24.0% < threshold, RESTARTING...
# [Gen 175] Diversity 22.0% < threshold, RESTARTING...
# [Gen 180] Diversity 24.0% < threshold, RESTARTING...
# [Gen 195] Diversity 22.0% < threshold, RESTARTING...
# [Gen 200] Best=  6872, Current=  6872, Diversity=34.0%, MutRate=30.0%, NoImprove=187
# [Gen 203] Diversity 24.0% < threshold, RESTARTING...
# [Gen 217] Diversity 24.0% < threshold, RESTARTING...
# [Gen 221] Diversity 24.0% < threshold, RESTARTING...
# [Gen 232] Diversity 23.0% < threshold, RESTARTING...
# [Gen 239] Diversity 17.0% < threshold, RESTARTING...
# [Gen 245] Diversity 24.0% < threshold, RESTARTING...
# [Gen 250] Best=  6872, Current=  6872, Diversity=34.0%, MutRate=30.0%, NoImprove=237
# [Gen 251] Diversity 24.0% < threshold, RESTARTING...
# [Gen 259] Diversity 24.0% < threshold, RESTARTING...
# [Gen 268] Diversity 23.0% < threshold, RESTARTING...
# [Gen 278] Diversity 22.0% < threshold, RESTARTING...
# [Gen 283] Diversity 22.0% < threshold, RESTARTING...
# [Gen 293] Diversity 19.0% < threshold, RESTARTING...
# [Gen 300] Best=  6872, Current=  6872, Diversity=35.0%, MutRate=30.0%, NoImprove=287
# [Gen 305] Diversity 20.0% < threshold, RESTARTING...
# [Gen 313] Diversity 22.0% < threshold, RESTARTING...
# [Gen 325] Diversity 23.0% < threshold, RESTARTING...
# [Gen 330] Diversity 24.0% < threshold, RESTARTING...
# [Gen 335] Diversity 23.0% < threshold, RESTARTING...
# [Gen 340] Diversity 21.0% < threshold, RESTARTING...
# [Gen 346] Diversity 23.0% < threshold, RESTARTING...
# [Gen 350] Best=  6872, Current=  6872, Diversity=54.0%, MutRate=30.0%, NoImprove=337
# [Gen 359] Diversity 21.0% < threshold, RESTARTING...
# [Gen 364] Diversity 23.0% < threshold, RESTARTING...
# [Gen 376] Diversity 23.0% < threshold, RESTARTING...
# [Gen 391] Diversity 19.0% < threshold, RESTARTING...
# [Gen 398] Diversity 22.0% < threshold, RESTARTING...
# [Gen 400] Best=  6872, Current=  6872, Diversity=57.0%, MutRate=30.0%, NoImprove=387
# [Gen 408] Diversity 23.0% < threshold, RESTARTING...
# [Gen 413] Diversity 20.0% < threshold, RESTARTING...
# [Gen 428] Diversity 20.0% < threshold, RESTARTING...
# [Gen 433] Diversity 18.0% < threshold, RESTARTING...
# [Gen 440] Diversity 24.0% < threshold, RESTARTING...
# [Gen 447] Diversity 22.0% < threshold, RESTARTING...
# [Gen 450] Best=  6872, Current=  6872, Diversity=73.0%, MutRate=30.0%, NoImprove=437
# [Gen 453] Diversity 24.0% < threshold, RESTARTING...
# [Gen 458] Diversity 21.0% < threshold, RESTARTING...
# [Gen 463] Diversity 21.0% < threshold, RESTARTING...
# [Gen 470] Diversity 21.0% < threshold, RESTARTING...
# [Gen 475] Diversity 14.0% < threshold, RESTARTING...
# [Gen 481] Diversity 21.0% < threshold, RESTARTING...
# [Gen 486] Diversity 23.0% < threshold, RESTARTING...
# [Gen 492] Diversity 21.0% < threshold, RESTARTING...
# [Gen 500] Best=  6872, Current=  6872, Diversity=35.0%, MutRate=30.0%, NoImprove=487
#   [KẾT QUẢ] Genetic Algorithm    | Cost: 6872     | Gap:   0.84% | Time:  1.472s
#   Đang chạy: ACO...
#   [KẾT QUẢ] ACO                  | Cost: 6815     | Gap:   0.00% | Time:  1.736s
#   Đang chạy: Tabu Search (from NN)...
#   [KẾT QUẢ] Tabu Search          | Cost: 6815     | Gap:   0.00% | Time:  0.212s
#   BỎ QUA: Brute Force (N=16 > 10)
#   Đang chạy: Held-Karp (N<=21)...
#   [KẾT QUẢ] Held-Karp            | Cost: 6815     | Gap:   0.00% | Time:  1.637s
# --- Hoàn thành ULYSSES16 ---
#
#
# ========== ĐANG XỬ LÝ: ULYSSES22 ==========
# Đã tải ulysses22 (N=22), Chi phí tối ưu: 6971
#   Đang chạy: Nearest Neighbor...
#   [KẾT QUẢ] Nearest Neighbor     | Cost: 8155     | Gap:  16.98% | Time:  0.000s
#   Đang chạy: Nearest Insertion...
#   [KẾT QUẢ] Nearest Insertion    | Cost: 7642     | Gap:   9.63% | Time:  0.001s
#   Đang chạy: Christofides...
#   [KẾT QUẢ] Christofides         | Cost: 7378     | Gap:   5.84% | Time:  0.003s
#   Đang chạy: 2-Opt (from NN)...
#   [KẾT QUẢ] 2-Opt                | Cost: 6958     | Gap:  -0.19% | Time:  0.001s
#   Đang chạy: Simulated Annealing (from NN)...
#   [KẾT QUẢ] Simulated Annealing  | Cost: 6958     | Gap:  -0.19% | Time:  5.161s
#   Đang chạy: Genetic Algorithm...
# [Gen   1] Best=  8155, Current=  8155, Diversity=100.0%, MutRate=15.0%, NoImprove=0
# [Gen   2] Best=  8155, Current=  8155, Diversity=97.0%, MutRate=15.0%, NoImprove=1
# [Gen   3] Best=  7661, Current=  7661, Diversity=93.0%, MutRate=15.0%, NoImprove=0
# [Gen   4] Best=  7661, Current=  7661, Diversity=83.0%, MutRate=15.0%, NoImprove=1
# [Gen   5] Best=  7189, Current=  7189, Diversity=72.0%, MutRate=15.0%, NoImprove=0
# [Gen  50] Best=  7120, Current=  7120, Diversity=24.0%, MutRate=30.0%, NoImprove=33
# [Gen 55] Diversity 12.0% < threshold, RESTARTING...
# [Gen 60] Diversity 13.0% < threshold, RESTARTING...
# [Gen 64] Diversity 20.0% < threshold, RESTARTING...
# [Gen 68] Diversity 12.0% < threshold, RESTARTING...
# [Gen 72] Diversity 13.0% < threshold, RESTARTING...
# [Gen 76] Diversity 17.0% < threshold, RESTARTING...
# [Gen 80] Diversity 10.0% < threshold, RESTARTING...
# [Gen 84] Diversity 21.0% < threshold, RESTARTING...
# [Gen 100] Best=  7023, Current=  7023, Diversity=32.0%, MutRate=30.0%, NoImprove=45
# [Gen 111] Diversity 23.0% < threshold, RESTARTING...
# [Gen 119] Diversity 23.0% < threshold, RESTARTING...
# [Gen 131] Diversity 21.0% < threshold, RESTARTING...
# [Gen 139] Diversity 23.0% < threshold, RESTARTING...
# [Gen 147] Diversity 23.0% < threshold, RESTARTING...
# [Gen 150] Best=  7023, Current=  7023, Diversity=75.0%, MutRate=30.0%, NoImprove=95
# [Gen 155] Diversity 22.0% < threshold, RESTARTING...
# [Gen 161] Diversity 24.0% < threshold, RESTARTING...
# [Gen 167] Diversity 19.0% < threshold, RESTARTING...
# [Gen 178] Diversity 24.0% < threshold, RESTARTING...
# [Gen 190] Diversity 22.0% < threshold, RESTARTING...
# [Gen 200] Best=  7023, Current=  7023, Diversity=26.0%, MutRate=30.0%, NoImprove=145
#   [KẾT QUẢ] Genetic Algorithm    | Cost: 6958     | Gap:  -0.19% | Time:  1.584s
#   Đang chạy: ACO...
#   [KẾT QUẢ] ACO                  | Cost: 7037     | Gap:   0.95% | Time:  2.327s
#   Đang chạy: Tabu Search (from NN)...
#   [KẾT QUẢ] Tabu Search          | Cost: 6958     | Gap:  -0.19% | Time:  0.407s
#   BỎ QUA: Brute Force (N=22 > 10)
#   BỎ QUA: Held-Karp (N=22 > 21)
# --- Hoàn thành ULYSSES22 ---
#
#
# --- TẤT CẢ THÍ NGHIỆM HOÀN TẤT ---

# %% [markdown]
# ## 4. Xử lý, Hiển thị và Lưu Kết quả
#
# Bây giờ chúng ta chuyển danh sách kết quả (list of dicts) thành một DataFrame `pandas` đẹp đẽ, tính toán `gap %` và lưu vào file `results.csv`.

# %%
import pandas as pd

# --- XEM LẠI KẾT QUẢ MỚI VỪA CHẠY ---
print("--- KẾT QUẢ MỚI TỪ LẦN CHẠY NÀY ---")
df_new = pd.DataFrame(all_results)

if not df_new.empty:
    # Sắp xếp lại cột cho df_new (đảm bảo tên khớp với vòng lặp)
    try:
        columns_order = [
            'problem', 'num_cities', 'algorithm', 
            'cost', 'opt_cost', 'gap_percent', 'time_sec'
        ]
        # Hiển thị tất cả kết quả mới
        print(df_new[columns_order].to_string())
    except KeyError:
        # Xử lý nếu tên cột không khớp (ví dụ: 'dimension' thay vì 'num_cities')
        print("Lỗi sắp xếp cột (KeyError), đang in kết quả thô:")
        print(df_new.to_string())
else:
    print("Không có kết quả mới nào được ghi nhận (danh sách 'all_results' rỗng).")


# --- 6. GỘP VÀ LƯU KẾT QUẢ VÀO FILE CSV (LOGIC AN TOÀN) ---
print("\n--- 6. LƯU KẾT QUẢ VÀO FILE CSV ---")
print("Đang gộp kết quả mới và cũ...")

# (Giả định 'df_existing' đã được tải ở cell phía trên)
df_final = pd.concat([df_existing, df_new], ignore_index=True)

# Loại bỏ các bản ghi trùng lặp, giữ lại bản ghi cuối cùng (mới nhất)
df_final = df_final.drop_duplicates(subset=['problem', 'algorithm'], keep='last')

# Sắp xếp lại
df_final = df_final.sort_values(by=['problem', 'algorithm'])

# Lưu file
try:
    df_final.to_csv(RESULTS_FILE, index=False)
    print(f"\nĐÃ LƯU KẾT QUẢ! Tổng cộng {len(df_final)} hàng trong {RESULTS_FILE}")
except Exception as e:
    print(f"\nLỖI: Không thể lưu file CSV. Lỗi: {e}")

# Hiển thị 5 hàng cuối cùng của file TỔNG
print("\n--- 5 hàng cuối cùng trong file CSV tổng ---")
# Sử dụng display() thay vì print() để Jupyter Notebook hiển thị bảng đẹp
display(df_final.tail(5))
# Out:
# --- KẾT QUẢ MỚI TỪ LẦN CHẠY NÀY ---
#        problem  num_cities            algorithm    cost  opt_cost  gap_percent     time_sec
# 0         a280         280     Nearest Neighbor    3157      2579       22.412     0.001327
# 1         a280         280    Nearest Insertion    3094      2579       19.969     0.046191
# 2         a280         280         Christofides    2914      2579       12.990     0.621953
# 3         a280         280                2-Opt    2767      2579        7.290     0.667864
# 4         a280         280  Simulated Annealing    2853      2579       10.624     5.642060
# 5         a280         280    Genetic Algorithm    2915      2579       13.028    40.972215
# 6         a280         280                  ACO    3077      2579       19.310    35.239364
# 7         a280         280          Tabu Search    2730      2579        5.855    80.401165
# 8        att48          48     Nearest Neighbor   12832     10598       21.079     0.000217
# 9        att48          48    Nearest Insertion   12012     10598       13.342     0.001587
# 10       att48          48         Christofides   12583     10598       18.730     0.025826
# 11       att48          48                2-Opt   10753     10598        1.463     0.008230
# 12       att48          48  Simulated Annealing   10598     10598        0.000     4.992095
# 13       att48          48    Genetic Algorithm   10892     10598        2.774     2.406790
# 14       att48          48                  ACO   11217     10598        5.841     4.864464
# 15       att48          48          Tabu Search   10878     10598        2.642     1.971773
# 16      bayg29          29     Nearest Neighbor    2005      1610       24.534     0.000140
# 17      bayg29          29    Nearest Insertion    1759      1610        9.255     0.000790
# 18      bayg29          29         Christofides    1765      1610        9.627     0.004772
# 19      bayg29          29                2-Opt    1794      1610       11.429     0.001812
# 20      bayg29          29  Simulated Annealing    1610      1610        0.000     4.781719
# 21      bayg29          29    Genetic Algorithm    1766      1610        9.689     1.662386
# 22      bayg29          29                  ACO    1655      1610        2.795     2.937382
# 23      bayg29          29          Tabu Search    1610      1610        0.000     0.714084
# 24      bays29          29     Nearest Neighbor    2258      2020       11.782     0.000136
# 25      bays29          29    Nearest Insertion    2262      2020       11.980     0.000802
# 26      bays29          29         Christofides    2123      2020        5.099     0.006507
# 27      bays29          29                2-Opt    2064      2020        2.178     0.001883
# 28      bays29          29  Simulated Annealing    2028      2020        0.396     4.893277
# 29      bays29          29    Genetic Algorithm    2048      2020        1.386     1.719101
# 30      bays29          29                  ACO    2055      2020        1.733     3.012058
# 31      bays29          29          Tabu Search    2020      2020        0.000     0.714672
# 32    berlin52          52     Nearest Neighbor    8980      7542       19.067     0.000226
# 33    berlin52          52    Nearest Insertion    8991      7542       19.212     0.001845
# 34    berlin52          52         Christofides    8591      7542       13.909     0.015271
# 35    berlin52          52                2-Opt    7967      7542        5.635     0.005104
# 36    berlin52          52  Simulated Annealing    7542      7542        0.000     4.911127
# 37    berlin52          52    Genetic Algorithm    7711      7542        2.241     2.614137
# 38    berlin52          52                  ACO    7706      7542        2.174     5.389216
# 39    berlin52          52          Tabu Search    7542      7542        0.000     2.357748
# 40       ch130         130     Nearest Neighbor    7579      6110       24.043     0.000545
# 41       ch130         130    Nearest Insertion    7446      6110       21.866     0.008681
# 42       ch130         130         Christofides    6773      6110       10.851     0.096313
# 43       ch130         130                2-Opt    6682      6110        9.362     0.112524
# 44       ch130         130  Simulated Annealing    6445      6110        5.483     5.133800
# 45       ch130         130    Genetic Algorithm    6622      6110        8.380    11.218498
# 46       ch130         130                  ACO    6596      6110        7.954    14.197742
# 47       ch130         130          Tabu Search    6442      6110        5.434    15.293710
# 48       ch150         150     Nearest Neighbor    8191      6528       25.475     0.000649
# 49       ch150         150    Nearest Insertion    7968      6528       22.059     0.013781
# 50       ch150         150         Christofides    7135      6528        9.298     0.123984
# 51       ch150         150                2-Opt    6886      6528        5.484     0.244373
# 52       ch150         150  Simulated Annealing    6828      6528        4.596     5.254305
# 53       ch150         150    Genetic Algorithm    6872      6528        5.270    13.981568
# 54       ch150         150                  ACO    6786      6528        3.952    16.643192
# 55       ch150         150          Tabu Search    6616      6528        1.348    20.286660
# 56      eil101         101     Nearest Neighbor     803       629       27.663     0.000402
# 57      eil101         101    Nearest Insertion     711       629       13.037     0.005489
# 58      eil101         101         Christofides     707       629       12.401     0.088450
# 59      eil101         101                2-Opt     658       629        4.610     0.078341
# 60      eil101         101  Simulated Annealing     664       629        5.564     5.147001
# 61      eil101         101    Genetic Algorithm     640       629        1.749     7.575908
# 62      eil101         101                  ACO     696       629       10.652    10.749153
# 63      eil101         101          Tabu Search     629       629        0.000     9.260612
# 64       eil51          51     Nearest Neighbor     511       426       19.953     0.000231
# 65       eil51          51    Nearest Insertion     494       426       15.962     0.001820
# 66       eil51          51         Christofides     462       426        8.451     0.013762
# 67       eil51          51                2-Opt     438       426        2.817     0.009816
# 68       eil51          51  Simulated Annealing     438       426        2.817     4.947106
# 69       eil51          51    Genetic Algorithm     434       426        1.878     2.606371
# 70       eil51          51                  ACO     450       426        5.634     5.482575
# 71       eil51          51          Tabu Search     427       426        0.235     2.181193
# 72       eil76          76     Nearest Neighbor     642       538       19.331     0.000304
# 73       eil76          76    Nearest Insertion     620       538       15.242     0.003231
# 74       eil76          76         Christofides     608       538       13.011     0.041597
# 75       eil76          76                2-Opt     558       538        3.717     0.019657
# 76       eil76          76  Simulated Annealing     559       538        3.903     4.959673
# 77       eil76          76    Genetic Algorithm     566       538        5.204     3.907724
# 78       eil76          76                  ACO     557       538        3.532     7.759478
# 79       eil76          76          Tabu Search     541       538        0.558     4.913665
# 80       fri26          26     Nearest Neighbor    1112       937       18.677     0.000134
# 81       fri26          26    Nearest Insertion    1056       937       12.700     0.000699
# 82       fri26          26         Christofides    1051       937       12.166     0.005513
# 83       fri26          26                2-Opt     955       937        1.921     0.002228
# 84       fri26          26  Simulated Annealing     937       937        0.000     4.865253
# 85       fri26          26    Genetic Algorithm     955       937        1.921     1.664764
# 86       fri26          26                  ACO     937       937        0.000     2.869198
# 87       fri26          26          Tabu Search     937       937        0.000     0.575806
# 88       gr120         120     Nearest Neighbor    9351      6942       34.702     0.000479
# 89       gr120         120    Nearest Insertion    8348      6942       20.254     0.007427
# 90       gr120         120         Christofides    8016      6942       15.471     0.172947
# 91       gr120         120                2-Opt    7278      6942        4.840     0.151811
# 92       gr120         120  Simulated Annealing    7092      6942        2.161     5.360955
# 93       gr120         120    Genetic Algorithm    7797      6942       12.316     9.638198
# 94       gr120         120                  ACO    7736      6942       11.438    12.922608
# 95       gr120         120          Tabu Search    7090      6942        2.132    12.927309
# 96       gr202         202     Nearest Neighbor   50318     40719       23.574     0.000856
# 97       gr202         202    Nearest Insertion   46908     40719       15.199     0.020796
# 98       gr202         202         Christofides   44038     40719        8.151     0.674297
# 145    kroC100         100    Nearest Insertion   26231     20749       26.421     0.005129
# 146    kroC100         100         Christofides   23470     20749       13.114     0.062281
# 147    kroC100         100                2-Opt   22129     20749        6.651     0.049536
# 148    kroC100         100  Simulated Annealing   21136     20749        1.865     5.001573
# 149    kroC100         100    Genetic Algorithm   22176     20749        6.877     6.620755
# 150    kroC100         100                  ACO   21664     20749        4.410    10.284012
# 151    kroC100         100          Tabu Search   21939     20749        5.735     8.969523
# 152    kroD100         100     Nearest Neighbor   26947     21294       26.547     0.000398
# 153    kroD100         100    Nearest Insertion   25219     21294       18.432     0.005238
# 154    kroD100         100         Christofides   23583     21294       10.750     0.068714
# 155    kroD100         100                2-Opt   22775     21294        6.955     0.083507
# 156    kroD100         100  Simulated Annealing   21708     21294        1.944     5.120162
# 157    kroD100         100    Genetic Algorithm   22620     21294        6.227     7.363525
# 158    kroD100         100                  ACO   23038     21294        8.190    10.462535
# 159    kroD100         100          Tabu Search   22007     21294        3.348     8.935373
# 160     lin105         105     Nearest Neighbor   20356     14379       41.568     0.000402
# 161     lin105         105    Nearest Insertion   18968     14379       31.915     0.005785
# 162     lin105         105         Christofides   16320     14379       13.499     0.066893
# 163     lin105         105                2-Opt   15601     14379        8.499     0.138558
# 164     lin105         105  Simulated Annealing   14831     14379        3.143     5.117540
# 165     lin105         105    Genetic Algorithm   15560     14379        8.213     7.206800
# 166     lin105         105                  ACO   14770     14379        2.719    10.741146
# 167     lin105         105          Tabu Search   14616     14379        1.648     9.906184
# 168      pa561         561     Nearest Neighbor    3422      2763       23.851     0.003315
# 169      pa561         561    Nearest Insertion    3431      2763       24.177     0.317347
# 170      pa561         561         Christofides    3179      2763       15.056     6.682058
# 171      pa561         561                2-Opt    3042      2763       10.098     5.880327
# 172      pa561         561  Simulated Annealing    3374      2763       22.114     6.066852
# 173      pa561         561    Genetic Algorithm    3242      2763       17.336   154.261624
# 174      pa561         561                  ACO    3302      2763       19.508    73.137905
# 175      pa561         561          Tabu Search    2902      2763        5.031   315.998019
# 176     pcb442         442     Nearest Neighbor   61979     50778       22.059     0.002023
# 177     pcb442         442    Nearest Insertion   61119     50778       20.365     0.181125
# 178     pcb442         442         Christofides   54868     50778        8.055     2.964763
# 179     pcb442         442                2-Opt   56308     50778       10.891     3.164384
# 180     pcb442         442  Simulated Annealing   57524     50778       13.285     6.406018
# 181     pcb442         442    Genetic Algorithm   57293     50778       12.830    99.629895
# 182     pcb442         442                  ACO   59798     50778       17.764    56.110637
# 183     pcb442         442          Tabu Search   52614     50778        3.616   197.117573
# 184     pr1002        1002     Nearest Neighbor  331103    259045       27.817     0.005593
# 185     pr1002        1002    Nearest Insertion  307430    259045       18.678     1.497835
# 186     pr1002        1002         Christofides  286203    259045       10.484    29.380255
# 187     pr1002        1002                2-Opt  318479    259045       22.944     4.250242
# 188     pr1002        1002  Simulated Annealing  331103    259045       27.817     5.605286
# 189     pr1002        1002    Genetic Algorithm  310142    259045       19.725   509.629628
# 190     pr1002        1002                  ACO  320257    259045       23.630   153.654981
# 191     pr1002        1002          Tabu Search  275274    259045        6.265  1054.232930
# 192     pr2392        2392     Nearest Neighbor  461170    378032       21.992     0.018482
# 193     pr2392        2392    Nearest Insertion  470702    378032       24.514    23.939305
# 194     pr2392        2392         Christofides  425940    378032       12.673   286.731649
# 195     pr2392        2392                2-Opt  452211    378032       19.622    20.112662
# 196     pr2392        2392  Simulated Annealing  461170    378032       21.992     6.067230
# 197     pr2392        2392    Genetic Algorithm  458399    378032       21.259  2405.850306
# 198     pr2392        2392                  ACO  492333    378032       30.236   498.225427
# 199     pr2392        2392          Tabu Search  398874    378032        5.513  6070.121844
# 200       pr76          76     Nearest Neighbor  153462    108159       41.886     0.001156
# 201       pr76          76    Nearest Insertion  128993    108159       19.262     0.007509
# 202       pr76          76         Christofides  116684    108159        7.882     0.045952
# 203       pr76          76                2-Opt  110714    108159        2.362     0.048281
# 204       pr76          76  Simulated Annealing  109394    108159        1.142     5.626739
# 205       pr76          76    Genetic Algorithm  116519    108159        7.729     4.772337
# 206       pr76          76                  ACO  118328    108159        9.402     7.950898
# 207       pr76          76          Tabu Search  109307    108159        1.061     5.209556
# 208      rd100         100     Nearest Neighbor    9938      7910       25.638     0.000413
# 209      rd100         100    Nearest Insertion    9485      7910       19.912     0.006855
# 210      rd100         100         Christofides    8906      7910       12.592     0.111261
# 211      rd100         100                2-Opt    8581      7910        8.483     0.083437
# 212      rd100         100  Simulated Annealing    8198      7910        3.641     5.232769
# 213      rd100         100    Genetic Algorithm    8419      7910        6.435     6.652833
# 214      rd100         100                  ACO    8443      7910        6.738    10.530536
# 215      rd100         100          Tabu Search    7988      7910        0.986     8.940412
# 216       st70          70     Nearest Neighbor     830       675       22.963     0.000287
# 217       st70          70    Nearest Insertion     821       675       21.630     0.003207
# 218       st70          70         Christofides     770       675       14.074     0.028110
# 219       st70          70                2-Opt     691       675        2.370     0.021936
# 220       st70          70  Simulated Annealing     685       675        1.481     5.177656
# 221       st70          70    Genetic Algorithm     701       675        3.852     4.004521
# 222       st70          70                  ACO     727       675        7.704     7.379628
# 223       st70          70          Tabu Search     685       675        1.481     4.274481
# 224     tsp225         225     Nearest Neighbor    4722      3861       22.300     0.000951
# 225     tsp225         225    Nearest Insertion    4750      3861       23.025     0.028003
# 226     tsp225         225         Christofides    4361      3861       12.950     0.336767
# 227     tsp225         225                2-Opt    4073      3861        5.491     0.563696
# 228     tsp225         225  Simulated Annealing    4160      3861        7.744     5.161312
# 229     tsp225         225    Genetic Algorithm    4430      3861       14.737    27.386801
# 230     tsp225         225                  ACO    4300      3861       11.370    24.602211
# 231     tsp225         225          Tabu Search    3971      3861        2.849    45.652080
# 232  ulysses16          16     Nearest Neighbor    9691      6815       42.201     0.000097
# 233  ulysses16          16    Nearest Insertion    7401      6815        8.599     0.000490
# 234  ulysses16          16         Christofides    6994      6815        2.627     0.001679
# 235  ulysses16          16                2-Opt    6815      6815        0.000     0.000510
# 236  ulysses16          16  Simulated Annealing    6815      6815        0.000     4.909925
# 237  ulysses16          16    Genetic Algorithm    6872      6815        0.836     1.472446
# 238  ulysses16          16                  ACO    6815      6815        0.000     1.736491
# 239  ulysses16          16          Tabu Search    6815      6815        0.000     0.211756
# 240  ulysses16          16            Held-Karp    6815      6815        0.000     1.636993
# 241  ulysses22          22     Nearest Neighbor    8155      6971       16.985     0.000146
# 242  ulysses22          22    Nearest Insertion    7642      6971        9.626     0.000572
# 243  ulysses22          22         Christofides    7378      6971        5.838     0.003146
# 244  ulysses22          22                2-Opt    6958      6971       -0.186     0.001064
# 245  ulysses22          22  Simulated Annealing    6958      6971       -0.186     5.160627
# 246  ulysses22          22    Genetic Algorithm    6958      6971       -0.186     1.583581
# 247  ulysses22          22                  ACO    7037      6971        0.947     2.327233
# 248  ulysses22          22          Tabu Search    6958      6971       -0.186     0.406516
#
# --- 6. LƯU KẾT QUẢ VÀO FILE CSV ---
# Đang gộp kết quả mới và cũ...
#
# ĐÃ LƯU KẾT QUẢ! Tổng cộng 249 hàng trong ../results/results.csv
#
# --- 5 hàng cuối cùng trong file CSV tổng ---
#        problem            algorithm  num_cities    cost  opt_cost  \
# 246  ulysses22    Genetic Algorithm        22.0  6958.0    6971.0
# 242  ulysses22    Nearest Insertion        22.0  7642.0    6971.0
# 241  ulysses22     Nearest Neighbor        22.0  8155.0    6971.0
# 245  ulysses22  Simulated Annealing        22.0  6958.0    6971.0
# 248  ulysses22          Tabu Search        22.0  6958.0    6971.0
#
#      gap_percent  time_sec
# 246       -0.186  1.583581
# 242        9.626  0.000572
# 241       16.985  0.000146
# 245       -0.186  5.160627
# 248       -0.186  0.406516

# %% [markdown]
# ## 5. Phân tích Nhanh
#
# Hãy nhóm theo thuật toán và tính toán trung bình `gap_percent` và `time`.

# %%
# Sửa lỗi: Thay thế df_results bằng df_final (chứa tất cả kết quả đã lưu)

# Đảm bảo bạn đã chạy cell lưu trữ và df_final đã được tạo thành công
if not df_final.empty:
    print("\n--- PHÂN TÍCH NHANH (TRUNG BÌNH) ---")
    
    # Chúng ta chỉ tính trung bình cho các vấn đề Heuristic (N > 21)
    # Tên cột trong df_final là 'num_cities'
    heuristic_results = df_final[df_final['num_cities'] > 21]

    if not heuristic_results.empty:
        # Tên cột trong df_final là 'time_sec'
        analysis = heuristic_results.groupby('algorithm')[['gap_percent', 'time_sec']].mean()
        analysis = analysis.sort_values(by='gap_percent')
        
        print("\nBảng Phân tích Trung bình (N > 21):")
        print(analysis)
        
    else:
        print("Không có kết quả từ các vấn đề lớn (N>21) để phân tích.")
else:
    print("Không có kết quả nào được tạo ra.")
# Out:
# --- PHÂN TÍCH NHANH (TRUNG BÌNH) ---
#
# Bảng Phân tích Trung bình (N > 21):
#                      gap_percent    time_sec
# algorithm
# Tabu Search             2.388200  279.617422
# Simulated Annealing     5.398433    5.262776
# 2-Opt                   6.901967    1.348249
# Genetic Algorithm       7.763167  119.398484
# ACO                     8.846467   37.665931
# Christofides           11.489333   11.436591
# Nearest Insertion      18.375967    0.888203
# Nearest Neighbor       24.541967    0.001466
